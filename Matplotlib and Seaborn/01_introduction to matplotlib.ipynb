# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,5,6])

# %%
years = [1990,1992,1994,1996,1998,2000,2003,2005,2007,2010]
runs = [500,700,1100,1500,1800,1200,1700,1300,900,1500]
plt.plot(years,runs)

# %%
plt.plot(years, runs)
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Sachin Tendulkar's Yearly Runs")
# Out:
# Text(0.5, 1.0, "Sachin Tendulkar's Yearly Runs")

# %%
years = list(range(2010, 2020))

kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

plt.plot(years, kohli, label="Virat Kohli")
plt.plot(years, sehwag, label="Virender Sehwag")

plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
# plt.show()

# %%
plt.plot(years, kohli, "ro--", label="Kohli")
plt.plot(years, sehwag, "g^:", label="Sehwag")

# %%
plt.plot(years, kohli, color='orange', linestyle='--', label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag")
plt.plot(years, runs, color='blue', label="Tendulkar")
plt.legend()

# %%
plt.plot(years, kohli, linewidth=3, label="Kohli")
plt.plot(years, sehwag, linewidth=2, label="Sehwag")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# plt.style.use("ggplot")
plt.style.use("seaborn-v0_8-bright")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\booksenv\lib\site-packages\matplotlib\style\core.py in use(style)
#     120             try:
# --> 121                 rc = rc_params_from_file(style, use_default_template=False)
#     122                 _apply_style(rc)
#
# ~\anaconda3\envs\booksenv\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     882     """
# --> 883     config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     884
#
# ~\anaconda3\envs\booksenv\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     811     rc_temp = {}
# --> 812     with _open_file_or_url(fname) as fd:
#     813         try:
#
# ~\anaconda3\envs\booksenv\lib\contextlib.py in __enter__(self)
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#
# ~\anaconda3\envs\booksenv\lib\site-packages\matplotlib\__init__.py in _open_file_or_url(fname)
#     789             encoding = "utf-8"
# --> 790         with open(fname, encoding=encoding) as f:
#     791             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn-v0_8-bright'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-38-acac37396abb> in <module>
#       6 plt.show()
#       7 # plt.style.use("ggplot")
# ----> 8 plt.style.use("seaborn-v0_8-bright")
#
# ~\anaconda3\envs\booksenv\lib\site-packages\matplotlib\style\core.py in use(style)
#     125                     "{!r} not found in the style library and input is not a "
#     126                     "valid URL or path; see `style.available` for list of "
# --> 127                     "available styles".format(style)) from err
#     128
#     129
#
# OSError: 'seaborn-v0_8-bright' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
with plt.xkcd():
    plt.plot(years, kohli, label="Kohli")
    plt.plot(years, sehwag, label="Sehwag")
    plt.title("Epic Battle of the Batsmen")
    plt.legend()
    plt.show()
