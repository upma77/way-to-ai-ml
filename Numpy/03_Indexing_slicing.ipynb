# %% [markdown]
# **indexing (Same as Python Lists)**

# %%
import numpy as pd

# %%
arr = pd.array([10,20,30,40])
print(arr[0])
print(arr[-1])
# Out:
# 10
# 40

# %% [markdown]
# **Slicing(Extracting Parts of an array)**

# %%
arr = pd.array([10,20,30,40,50])
print(arr[1:4])
# Out:
# [20 30 40]

# %%
print(arr[:3])
# Out:
# [10 20 30]

# %%
print(arr[::2])
# Out:
# [10 30 50]

# %% [markdown]
# **Slicing returns a view, not a copy changes affect the original array**

# %% [markdown]
# this might seem counterintuitive since python  lists create copies when sliced. but in numpy,slicing returns a view of the original array.Both the sliced array and the original array share the same data in memory,so changes in the slice affect the original array.

# %% [markdown]
# this happens because -
#  - memory effeciancy : Avoid unnecessary copies,making operation faster and saving memory.
#  - performance  : Enables faster access and manipulation of large datasets without duuplicating data.

# %%
sliced = arr[1:4]

# %%
sliced[0] = 999

# %%
print(arr)
# Out:
# [ 10 999  30  40  50]

# %% [markdown]
# **Fancy Indexing and Boolean Masking**

# %% [raw]
# arr = pd.array([10,20,30,40,50])

# %%
idx = [0,2,4]
print(arr[idx])
# Out:
# [10 30 50]

# %% [markdown]
# **Boolean Masking (Filter Data)**

# %%
arr = pd.array([10,20,30,40,50])
mask = arr > 25
print(arr[mask])
# Out:
# [30 40 50]
