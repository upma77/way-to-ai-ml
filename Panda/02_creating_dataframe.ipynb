# %%
import pandas as pd

# %% [markdown]
# from python lists

# %%
data = [
["Alice",35],
["Bob",30],
["Charlie",35]
]
df = pd.DataFrame(data, columns=["Name","Age"], index=["q","w","r"])
df
# Out:
#       Name  Age
# q    Alice   35
# w      Bob   30
# r  Charlie   35

# %%
df.index=["a","b","c"]
df
# Out:
#       Name  Age
# a    Alice   35
# b      Bob   30
# c  Charlie   35

# %% [markdown]
# From Dictionary of Lists

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35]
}

df = pd.DataFrame(data)
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}

# %% [markdown]
# From NumPy Arrays

# %%
import numpy as np

arr = np.array([[1, 2], [3, 4]])
# df = pd.DataFrame(arr, columns=["A", "B"])
df
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df = pd.read_csv("data.csv")
df
# Out:
#       Name School  Marks
# 0     upma   upes     99
# 1   ruhani   upes     98
# 2  rimjhim     sr     97
# 3    vidya  bihar     96
# 4  aarushi  bihar     95

# %%
import pandas as pd
pd.read_csv("data.csv", usecols=["Name", "School","Marks"])
# Out:
#       Name School  Marks
# 0     upma   upes     99
# 1   ruhani   upes     98
# 2  rimjhim     sr     97
# 3    vidya  bihar     96
# 4  aarushi  bihar     95

# %%
df = pd.read_csv("data.csv")
df
# Out:
#       Name School  Marks
# 0     upma   upes     99
# 1   ruhani   upes     98
# 2  rimjhim     sr     97
# 3    vidya  bihar     96
# 4  aarushi  bihar     95
