# %%
import pandas as pd

# %%
df = pd.read_csv("Data_transforming.csv")

# %%
df
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 0                        Dangal           Aamir Khan  2016      Sports Biopic
# 1   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 2     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 3                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 4                 KGF Chapter 2                 Yash  2022    Action Thriller
# 5                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 6                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 7                 Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
# 8             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
# 9              Secret Superstar           Aamir Khan  2017   Musical / Family
# 10                       Animal        Ranbir Kapoor  2023       Action Crime
#
# ...

# %%
df.sort_values("Year")
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 8             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
# 0                        Dangal           Aamir Khan  2016      Sports Biopic
# 1   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 9              Secret Superstar           Aamir Khan  2017   Musical / Family
# 3                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 4                 KGF Chapter 2                 Yash  2022    Action Thriller
# 5                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 6                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 10                       Animal        Ranbir Kapoor  2023       Action Crime
# 2     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 7                 Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
#
# ...

# %%
df.sort_values(["Year", "IMDb Rating"])
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 8             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
# 0                        Dangal           Aamir Khan  2016      Sports Biopic
# 1   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 9              Secret Superstar           Aamir Khan  2017   Musical / Family
# 3                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 4                 KGF Chapter 2                 Yash  2022    Action Thriller
# 10                       Animal        Ranbir Kapoor  2023       Action Crime
# 6                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 5                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 2     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 7                 Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
#
# ...

# %%
df.sort_values("Year", ascending=False)
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 2     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 7                 Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
# 5                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 6                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 10                       Animal        Ranbir Kapoor  2023       Action Crime
# 3                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 4                 KGF Chapter 2                 Yash  2022    Action Thriller
# 1   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 9              Secret Superstar           Aamir Khan  2017   Musical / Family
# 0                        Dangal           Aamir Khan  2016      Sports Biopic
# 8             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
#
# ...

# %%
df2 = df.sort_values(["Year","IMDb Rating"]).copy()

# %%
df2
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 8             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
# 0                        Dangal           Aamir Khan  2016      Sports Biopic
# 1   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 9              Secret Superstar           Aamir Khan  2017   Musical / Family
# 3                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 4                 KGF Chapter 2                 Yash  2022    Action Thriller
# 10                       Animal        Ranbir Kapoor  2023       Action Crime
# 6                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 5                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 2     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 7                 Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
#
# ...

# %%
df2.reset_index()
# Out:
#     index                        Movie        Lead Actor(s)  Year  \
# 0       8            Bajrangi Bhaijaan          Salman Khan  2015
# 1       0                       Dangal           Aamir Khan  2016
# 2       1  Baahubali 2: The Conclusion              Prabhas  2017
# 3       9             Secret Superstar           Aamir Khan  2017
# 4       3                          RRR  Jr. NTR, Ram Charan  2022
# 5       4                KGF Chapter 2                 Yash  2022
# 6      10                       Animal        Ranbir Kapoor  2023
# 7       6                      Pathaan       Shah Rukh Khan  2023
# 8       5                        Jawan       Shah Rukh Khan  2023
# 9       2    Pushpa: The Rule – Part 2           Allu Arjun  2024
# 10      7                Kalki 2898 AD              Prabhas  2024
#
#                 Genre  Worldwide Gross (INR Cr)  IMDb Rating
# 0      Drama / Social                       920          8.0
# ...

# %%
df2.reset_index(drop=True)
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 0             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
# 1                        Dangal           Aamir Khan  2016      Sports Biopic
# 2   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 3              Secret Superstar           Aamir Khan  2017   Musical / Family
# 4                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 5                 KGF Chapter 2                 Yash  2022    Action Thriller
# 6                        Animal        Ranbir Kapoor  2023       Action Crime
# 7                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 8                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 9     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 10                Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
#
# ...

# %%
df2.reset_index(drop=True,inplace=True)#in[lace krne se jo original data frame h whi update ho jata h

# %%
df2
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 0             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
# 1                        Dangal           Aamir Khan  2016      Sports Biopic
# 2   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 3              Secret Superstar           Aamir Khan  2017   Musical / Family
# 4                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 5                 KGF Chapter 2                 Yash  2022    Action Thriller
# 6                        Animal        Ranbir Kapoor  2023       Action Crime
# 7                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 8                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 9     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 10                Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
#
# ...

# %%
df2["Rank"] = df2["IMDb Rating"].rank(ascending=False)

# %%
 df2
# Out:
#                           Movie        Lead Actor(s)  Year              Genre  \
# 0             Bajrangi Bhaijaan          Salman Khan  2015     Drama / Social
# 1                        Dangal           Aamir Khan  2016      Sports Biopic
# 2   Baahubali 2: The Conclusion              Prabhas  2017  Epic / Historical
# 3              Secret Superstar           Aamir Khan  2017   Musical / Family
# 4                           RRR  Jr. NTR, Ram Charan  2022      Period Action
# 5                 KGF Chapter 2                 Yash  2022    Action Thriller
# 6                        Animal        Ranbir Kapoor  2023       Action Crime
# 7                       Pathaan       Shah Rukh Khan  2023         Spy Action
# 8                         Jawan       Shah Rukh Khan  2023    Action Thriller
# 9     Pushpa: The Rule – Part 2           Allu Arjun  2024     Action / Drama
# 10                Kalki 2898 AD              Prabhas  2024      Sci-Fi / Epic
#
# ...

# %%
cols = ["Year"] + [col for col in df.columns if col != "Year"]
df = df[cols]

# %%
df
# Out:
#     Year                        Movie        Lead Actor(s)              Genre  \
# 0   2016                       Dangal           Aamir Khan      Sports Biopic
# 1   2017  Baahubali 2: The Conclusion              Prabhas  Epic / Historical
# 2   2024    Pushpa: The Rule – Part 2           Allu Arjun     Action / Drama
# 3   2022                          RRR  Jr. NTR, Ram Charan      Period Action
# 4   2022                KGF Chapter 2                 Yash    Action Thriller
# 5   2023                        Jawan       Shah Rukh Khan    Action Thriller
# 6   2023                      Pathaan       Shah Rukh Khan         Spy Action
# 7   2024                Kalki 2898 AD              Prabhas      Sci-Fi / Epic
# 8   2015            Bajrangi Bhaijaan          Salman Khan     Drama / Social
# 9   2017             Secret Superstar           Aamir Khan   Musical / Family
# 10  2023                       Animal        Ranbir Kapoor       Action Crime
#
# ...
